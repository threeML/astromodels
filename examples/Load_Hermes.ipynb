# %%
from astromodels import *

list_functions()
# Out:
# /Users/rishi/Documents/Analysis/astromodels/astromodels/utils/file_utils.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 14:14:14 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=855516;file:///Users/rishi/Documents/Analysis/astromodels/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=174611;file:///Users/rishi/Documents/Analysis/astromodels/astromodels/functions/functions_1D/functions.py#47\47]8;;\
#                   available
# ...

# %%
Hermes.info()
# Out:
# <ul>
#
# <li>description: Use a 3D template that has morphology and flux information created using the HERMES sky-maps in fits format. Only parameter is the normalization scale factor N.</li>
#
# <li>formula: $ N $</li>
#
# <li>default parameters:
# <ul>
#
# <li>N:
# <ul>
#
# <li>value: 1.0</li>
#
# <li>desc: normalization scale factor</li>
#
# <li>min_value: None</li>
#
# <li>max_value: None</li>
#
# <li>unit: </li>
#
# <li>is_normalization: False</li>
#
# <li>delta: 0.1</li>
#
# <li>free: False</li>
#
# </ul>
#
# </li>
#
# <li>hash:
# <ul>
#
# <li>value: 1.0</li>
#
# <li>desc: hash of model map [needed for memoization]</li>
#
# <li>min_value: None</li>
#
# <li>max_value: None</li>
#
# <li>unit: </li>
#
# <li>is_normalization: False</li>
#
# <li>delta: 0.1</li>
#
# <li>free: False</li>
#
# </ul>
#
# </li>
#
# <li>ihdu:
# <ul>
#
# <li>value: 0.0</li>
#
# <li>desc: header unit index of fits file</li>
#
# <li>min_value: 0.0</li>
#
# <li>max_value: None</li>
#
# <li>unit: </li>
#
# ...

# %%
Template = Hermes(fits_file="Hermes.fits.gz", ihdu=0)

# %%
Template.display()
# Out:
#   * description: Use a 3D template that has morphology and flux information created using
#     * the HERMES sky-maps in fits format. Only parameter is the normalization scale factor
#     * N.
#   * formula: $ N $
#   * parameters:
#     * N:
#       * value: 1.0
#       * desc: normalization scale factor
#       * min_value: null
#       * max_value: null
#       * unit: ''
#       * is_normalization: false
#       * delta: 0.1
#       * free: false
#     * hash:
#       * value: 1.5662361134184995e+67
#       * desc: hash of model map [needed for memoization]
#       * min_value: null
#       * max_value: null
#       * unit: ''
#       * is_normalization: false
#       * delta: 0.1
#       * free: false
#     * ihdu:
#       * value: 0.0
#       * desc: header unit index of fits file
#       * min_value: 0.0
#       * max_value: null
#       * unit: ''
#       * is_normalization: false
#       * delta: 0.1
#       * free: false
#     * fits_file:
#       * value: Hermes.fits.gz
# ...

# %%
print(Template)
# Out:
#   * description: Use a 3D template that has morphology and flux information created using
#     * the HERMES sky-maps in fits format. Only parameter is the normalization scale factor
#     * N.
#   * formula: $ N $
#   * parameters:
#     * N:
#       * value: 1.0
#       * desc: normalization scale factor
#       * min_value: null
#       * max_value: null
#       * unit: ''
#       * is_normalization: false
#       * delta: 0.1
#       * free: false
#     * hash:
#       * value: 1.5662361134184995e+67
#       * desc: hash of model map [needed for memoization]
#       * min_value: null
#       * max_value: null
#       * unit: ''
#       * is_normalization: false
#       * delta: 0.1
#       * free: false
#     * ihdu:
#       * value: 0.0
#       * desc: header unit index of fits file
#       * min_value: 0.0
#       * max_value: null
#       * unit: ''
#       * is_normalization: false
#       * delta: 0.1
#       * free: false
#     * fits_file:
#       * value: Hermes.fits.gz
# ...

# %%
print("Unit of K is [%s]" % Template.N.unit)
# Out:
# Unit of K is []
